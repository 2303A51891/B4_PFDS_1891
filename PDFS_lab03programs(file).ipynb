# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51891/B4_PFDS_1891/blob/main/PDFS_lab03programs(file).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Problem1

import numpy as np

a = np.random.randint(1, 10, (3, 3))
b = np.random.randint(1, 10, (3, 3))

add = np.add(a, b)
sub = np.subtract(a, b)

print("Matrix A:\n", a)
print("Matrix B:\n", b)
print("Addition:\n", add)
print("Subtraction:\n", sub)
# Out:
# Matrix A:
#  [[5 2 6]
#  [3 5 5]
#  [5 4 9]]
# Matrix B:
#  [[9 6 9]
#  [9 1 5]
#  [8 3 3]]
# Addition:
#  [[14  8 15]
#  [12  6 10]
#  [13  7 12]]
# Subtraction:
#  [[-4 -4 -3]
#  [-6  4  0]
#  [-3  1  6]]

# %%
#Problem 2

import numpy as np
import matplotlib.pyplot as plt

a = np.random.randint(1, 5, (3, 2))
b = np.random.randint(1, 5, (2, 3))
c = np.dot(a, b)

print("Matrix A:\n", a)
print("Matrix B:\n", b)
print("Dot Product:\n", c)


plt.figure(figsize=(8, 3))

plt.subplot(1, 3, 1)
plt.imshow(a, cmap='viridis', interpolation='nearest')
plt.title("Matrix A")
plt.colorbar()

plt.subplot(1, 3, 2)
plt.imshow(b, cmap='viridis', interpolation='nearest')
plt.title("Matrix B")
plt.colorbar()

plt.subplot(1, 3, 3)
plt.imshow(c, cmap='viridis', interpolation='nearest')
plt.title("Dot Product")
plt.colorbar()

plt.tight_layout()
plt.show()
# Out:
# Matrix A:
#  [[1 3]
#  [1 1]
#  [2 4]]
# Matrix B:
#  [[3 3 4]
#  [4 4 2]]
# Dot Product:
#  [[15 15 10]
#  [ 7  7  6]
#  [22 22 16]]

# %% [markdown]
# Classroom Activity

# %%
#ClassRoom_Files
import csv

with open("Classroom_file.csv", 'w', newline='') as fp:
    wr = csv.writer(fp)
    wr.writerow(["Name", "Marks"])
    for i in range(2):
        name = input("Enter name: ")
        marks = int(input("Enter marks: "))
        wr.writerow([name, marks])
# Out:
# Enter name: anirudh
# Enter marks: 88
# Enter name: subhani
# Enter marks: 90
